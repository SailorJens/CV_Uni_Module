# %%
from ultralytics import YOLO

# Detection model
model_det = YOLO("yolov12n.pt")

# Segmentation model
model_seg = YOLO("yolov12n-seg.pt")

print("Models loaded (and cached).")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/jus/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from ultralytics import YOLO
#       3 # Detection model
# ----> 4 model_det = YOLO("yolov12n.pt")
#       6 # Segmentation model
#       7 model_seg = YOLO("yolov12n-seg.pt")
#
# File ~/Documents/Code/CV_Uni_Module/.venv/lib/python3.14/site-packages/ultralytics/models/yolo/model.py:76, in YOLO.__init__(self, model, task, verbose)
#      73     self.__dict__ = new_instance.__dict__
#      74 else:
#      75     # Continue with default YOLO initialization
# ...

# %%
import ultralytics
ultralytics.__version__
# Out:
# '8.4.7'

# %%
from ultralytics import YOLO

YOLO("https://github.com/ultralytics/assets/releases/download/v12.0/yolov12n.pt")
YOLO("https://github.com/ultralytics/assets/releases/download/v12.0/yolov12n-seg.pt")
# Out:
# WARNING ⚠️ Download failure, retrying 1/3 https://github.com/ultralytics/assets/releases/download/v12.0/yolov12n.pt... HTTP Error 404: Not Found
# ######################################################################## 100.0%
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[3], line 3
#       1 from ultralytics import YOLO
# ----> 3 YOLO("https://github.com/ultralytics/assets/releases/download/v12.0/yolov12n.pt")
#       4 YOLO("https://github.com/ultralytics/assets/releases/download/v12.0/yolov12n-seg.pt")
#
# File ~/Documents/Code/CV_Uni_Module/.venv/lib/python3.14/site-packages/ultralytics/models/yolo/model.py:76, in YOLO.__init__(self, model, task, verbose)
#      73     self.__dict__ = new_instance.__dict__
#      74 else:
#      75     # Continue with default YOLO initialization
# ---> 76     super().__init__(model=model, task=task, verbose=verbose)
# ...

# %%
from pathlib import Path

cache = Path.home() / ".cache" / "ultralytics"
list(cache.glob("*yolov12n*.pt"))
# Out:
# []

# %%
f = cache / "yolov12n.pt"
f.stat().st_size
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 f = cache / "yolov12n.pt"
# ----> 2 f.stat().st_size
#
# File /opt/homebrew/Cellar/python@3.14/3.14.0/Frameworks/Python.framework/Versions/3.14/lib/python3.14/pathlib/__init__.py:659, in Path.stat(self, follow_symlinks)
#     654 def stat(self, *, follow_symlinks=True):
#     655     """
#     656     Return the result of the stat() system call on this path, like
#     657     os.stat() does.
#     658     """
# --> 659     return os.stat(self, follow_symlinks=follow_symlinks)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/jus/.cache/ultralytics/yolov12n.pt'

# %%
print(ultralytics.__version__)
# Out:
# 8.4.7

# %%
from ultralytics import YOLO

# This should download the YOLO12n detection model
model_det = YOLO("https://github.com/ultralytics/assets/releases/latest/download/yolov12n.pt")
# Out:
# Found https://github.com/ultralytics/assets/releases/latest/download/yolov12n.pt locally at /Users/jus/Documents/Code/CV_Uni_Module/weights/yolov12n.pt
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[7], line 4
#       1 from ultralytics import YOLO
#       3 # This should download the YOLO12n detection model
# ----> 4 model_det = YOLO("https://github.com/ultralytics/assets/releases/latest/download/yolov12n.pt")
#
# File ~/Documents/Code/CV_Uni_Module/.venv/lib/python3.14/site-packages/ultralytics/models/yolo/model.py:76, in YOLO.__init__(self, model, task, verbose)
#      73     self.__dict__ = new_instance.__dict__
#      74 else:
#      75     # Continue with default YOLO initialization
# ---> 76     super().__init__(model=model, task=task, verbose=verbose)
# ...

# %%
from ultralytics import YOLO

# Create a new YOLO model from scratch
model = YOLO("yolo26n.yaml")

# Load a pretrained YOLO model (recommended for training)
model = YOLO("yolo26n.pt")

# Train the model using the 'coco8.yaml' dataset for 3 epochs
results = model.train(data="coco8.yaml", epochs=3)

# Evaluate the model's performance on the validation set
results = model.val()

# Perform object detection on an image using the model
results = model("https://ultralytics.com/images/bus.jpg")
# Out:
# ...
# Ultralytics 8.4.7 🚀 Python-3.14.0 torch-2.9.1 CPU (Apple M2)
# ...

# %%
model = YOLO("yolo26n-seg.pt")  # load an official segmentation model
